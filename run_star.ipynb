# %%
from pathlib import Path
import subprocess
import traceback
import argparse

# %%
"""
"""
STAR --runThreadN 2 -runMode alignReads --readFilesIn 7KO-Cyto-BS_processed_fastqs/KEH-Rep1-7KO-HEK293T-Cyto-BS --genomeDir /home/lingsn/Software/genome_indices/hisat2_hg38/hg38p14_tran/GCF_000001405.40_GRCh38.p14_tran* --outFileNamePrefix 7KO-Cyto-BS_processed_fastqs/alignments/star --outSAMtype BAM SortedByCoordinate
